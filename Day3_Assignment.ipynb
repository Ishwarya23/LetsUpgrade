# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.shape
# Out:
# (1064, 5)

# %%
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
fmri.region.unique()
# Out:
# array(['parietal', 'frontal'], dtype=object)

# %%
fmri.event.unique()
# Out:
# array(['stim', 'cue'], dtype=object)

# %%
sns.relplot(x='timepoint',y='signal',hue='event',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',kind='line',hue='event',col='region',data=fmri)

# %%
sns.scatterplot(x='timepoint',y='signal',hue='event',data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.catplot(x='region',y='signal',data=fmri)

# %%
sns.catplot(x='region',y='signal',data=fmri,hue='event')

# %%
sns.catplot(x='region',y='signal',data=fmri,hue='event',row='event',kind='swarm')
# Out:
# C:\Users\Ishwarya\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ishwarya\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ishwarya\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='event',y='signal',data=fmri,hue='region',kind='box')

# %%
sns.catplot(x='event',y='signal',data=fmri,hue='region',kind='violin',dodge=False)

# %%
sns.catplot(x='event',y='signal',data=fmri,hue='region',kind='violin')
